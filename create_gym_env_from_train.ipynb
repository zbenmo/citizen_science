# %%
# %load_ext autoreload
# %autoreload 2

# %%
from common import (
    get_starting_df,
    find_sessions,
    add_regression_target,
    calc_y,
    add_fold,
)
import polars as pl
import gymnasium as gym
from IPython import display

# %%
df = (
    get_starting_df()
    .pipe(find_sessions, 60 * 30)
    .pipe(add_regression_target)
)

y = calc_y(df)

# %%
df.pipe(add_fold, y).write_parquet("with_fold.parquest")

# %%
del df

# %%
df = pl.read_parquet("with_fold.parquest")

# %%
df.shape
# Out:
# (99999, 9)

# %%
df['session'].max()
# Out:
# 2289

# %%
df['user'].max()
# Out:
# 943

# %%
df['fold'].value_counts()
# Out:
# shape: (4, 2)
# ┌──────┬───────┐
# │ fold ┆ count │
# │ ---  ┆ ---   │
# │ i32  ┆ u32   │
# ╞══════╪═══════╡
# │ 3    ┆ 25004 │
# │ 0    ┆ 25023 │
# │ 1    ┆ 24986 │
# │ 2    ┆ 24986 │
# └──────┴───────┘

# %%
y.value_counts()
# Out:
# shape: (2, 2)
# ┌───────────┬───────┐
# │ disengage ┆ count │
# │ ---       ┆ ---   │
# │ bool      ┆ u32   │
# ╞═══════════╪═══════╡
# │ true      ┆ 32180 │
# │ false     ┆ 67819 │
# └───────────┴───────┘

# %%
class CitizenScienceEnv(gym.Env):
    def __init__(self, df, seed: int = 1):
        super().reset(seed=seed)
        self.df = (
            df
            .with_columns(time_passed=(pl.col('timestamp') - pl.col('timestamp').min().over('session')).dt.total_seconds())
        )
        self.sessions = self.df.unique('session')
        self.state_space = gym.spaces.Box(0, 6000, dtype=int)
        self.action_space = gym.spaces.Discrete(2) # 0 will not disengage, 1 will disengage
        self.session_entries = None
        self.entry = None

    def reset(self):
        session = self.sessions.sample()['session'].item()
        self.session_entries = self.df.filter(pl.col('session') == session).sort('timestamp')
        self.entry = 0
        return self._obs()

    def _obs(self):
        return self.session_entries[self.entry, 'timestamp'].timestamp(), {}
            
    def step(self, action):
        if action == 1:
            reward = 0
            terminated = True
            self.entry = None
            self.session_entries = None
        elif action == 0:
            if self.entry < self.session_entries.shape[0] - 1:
                reward = self.session_entries[self.entry, 'time_passed']
                self.entry += 1
                terminated = False
            else:
                reward = -5000
                terminated = True
                # self.entry = None
                # self.session_entries = None
        else:
            assert False
        obs, info = self._obs()
        truncated = False
        return obs, reward, terminated, truncated, info

    def render(self):
        display.display(self.session_entries.to_pandas().style.apply(
            lambda col: [('background-color: yellow' if row == self.entry else '') for row, _ in enumerate(col)]
        ))

# %%
env = CitizenScienceEnv(df.filter(pl.col('fold') != 0))

# %%
env.reset()
# Out:
# (1420354030.0, {})

# %%
env.render()
# Out:
# <style type="text/css">
# #T_eb9b3_row0_col0, #T_eb9b3_row0_col1, #T_eb9b3_row0_col2, #T_eb9b3_row0_col3, #T_eb9b3_row0_col4, #T_eb9b3_row0_col5, #T_eb9b3_row0_col6, #T_eb9b3_row0_col7, #T_eb9b3_row0_col8, #T_eb9b3_row0_col9 {
#   background-color: yellow;
# }
# </style>
# <table id="T_eb9b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb9b3_level0_col0" class="col_heading level0 col0" >user_id</th>
#       <th id="T_eb9b3_level0_col1" class="col_heading level0 col1" >timestamp</th>
#       <th id="T_eb9b3_level0_col2" class="col_heading level0 col2" >ts_diff</th>
#       <th id="T_eb9b3_level0_col3" class="col_heading level0 col3" >user_diff</th>
#       <th id="T_eb9b3_level0_col4" class="col_heading level0 col4" >new_session_mark</th>
#       <th id="T_eb9b3_level0_col5" class="col_heading level0 col5" >session</th>
#       <th id="T_eb9b3_level0_col6" class="col_heading level0 col6" >user</th>
#       <th id="T_eb9b3_level0_col7" class="col_heading level0 col7" >target</th>
#       <th id="T_eb9b3_level0_col8" class="col_heading level0 col8" >fold</th>
#       <th id="T_eb9b3_level0_col9" class="col_heading level0 col9" >time_passed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb9b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eb9b3_row0_col0" class="data row0 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row0_col1" class="data row0 col1" >2015-01-04 07:47:10</td>
#       <td id="T_eb9b3_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_eb9b3_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_eb9b3_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_eb9b3_row0_col5" class="data row0 col5" >2253</td>
#       <td id="T_eb9b3_row0_col6" class="data row0 col6" >915</td>
#       <td id="T_eb9b3_row0_col7" class="data row0 col7" >782</td>
#       <td id="T_eb9b3_row0_col8" class="data row0 col8" >3</td>
#       <td id="T_eb9b3_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_eb9b3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eb9b3_row1_col0" class="data row1 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row1_col1" class="data row1 col1" >2015-01-04 07:49:09</td>
#       <td id="T_eb9b3_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_eb9b3_row1_col3" class="data row1 col3" >False</td>
#       <td id="T_eb9b3_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_eb9b3_row1_col5" class="data row1 col5" >2253</td>
#       <td id="T_eb9b3_row1_col6" class="data row1 col6" >915</td>
#       <td id="T_eb9b3_row1_col7" class="data row1 col7" >663</td>
#       <td id="T_eb9b3_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_eb9b3_row1_col9" class="data row1 col9" >119</td>
#     </tr>
#     <tr>
#       <th id="T_eb9b3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eb9b3_row2_col0" class="data row2 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row2_col1" class="data row2 col1" >2015-01-04 07:49:24</td>
#       <td id="T_eb9b3_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_eb9b3_row2_col3" class="data row2 col3" >False</td>
#       <td id="T_eb9b3_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_eb9b3_row2_col5" class="data row2 col5" >2253</td>
#       <td id="T_eb9b3_row2_col6" class="data row2 col6" >915</td>
#       <td id="T_eb9b3_row2_col7" class="data row2 col7" >648</td>
#       <td id="T_eb9b3_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_eb9b3_row2_col9" class="data row2 col9" >134</td>
#     </tr>
#     <tr>
#       <th id="T_eb9b3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eb9b3_row3_col0" class="data row3 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row3_col1" class="data row3 col1" >2015-01-04 07:49:25</td>
#       <td id="T_eb9b3_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_eb9b3_row3_col3" class="data row3 col3" >False</td>
#       <td id="T_eb9b3_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_eb9b3_row3_col5" class="data row3 col5" >2253</td>
#       <td id="T_eb9b3_row3_col6" class="data row3 col6" >915</td>
#       <td id="T_eb9b3_row3_col7" class="data row3 col7" >647</td>
#       <td id="T_eb9b3_row3_col8" class="data row3 col8" >3</td>
#       <td id="T_eb9b3_row3_col9" class="data row3 col9" >135</td>
#     </tr>
#     <tr>
#       <th id="T_eb9b3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eb9b3_row4_col0" class="data row4 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row4_col1" class="data row4 col1" >2015-01-04 07:49:28</td>
#       <td id="T_eb9b3_row4_col2" class="data row4 col2" >False</td>
#       <td id="T_eb9b3_row4_col3" class="data row4 col3" >False</td>
#       <td id="T_eb9b3_row4_col4" class="data row4 col4" >False</td>
#       <td id="T_eb9b3_row4_col5" class="data row4 col5" >2253</td>
#       <td id="T_eb9b3_row4_col6" class="data row4 col6" >915</td>
#       <td id="T_eb9b3_row4_col7" class="data row4 col7" >644</td>
#       <td id="T_eb9b3_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_eb9b3_row4_col9" class="data row4 col9" >138</td>
#     </tr>
#     <tr>
#       <th id="T_eb9b3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eb9b3_row5_col0" class="data row5 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row5_col1" class="data row5 col1" >2015-01-04 07:49:58</td>
#       <td id="T_eb9b3_row5_col2" class="data row5 col2" >False</td>
#       <td id="T_eb9b3_row5_col3" class="data row5 col3" >False</td>
#       <td id="T_eb9b3_row5_col4" class="data row5 col4" >False</td>
#       <td id="T_eb9b3_row5_col5" class="data row5 col5" >2253</td>
#       <td id="T_eb9b3_row5_col6" class="data row5 col6" >915</td>
#       <td id="T_eb9b3_row5_col7" class="data row5 col7" >614</td>
#       <td id="T_eb9b3_row5_col8" class="data row5 col8" >3</td>
#       <td id="T_eb9b3_row5_col9" class="data row5 col9" >168</td>
#     </tr>
#     <tr>
#       <th id="T_eb9b3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eb9b3_row6_col0" class="data row6 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row6_col1" class="data row6 col1" >2015-01-04 07:50:19</td>
#       <td id="T_eb9b3_row6_col2" class="data row6 col2" >False</td>
#       <td id="T_eb9b3_row6_col3" class="data row6 col3" >False</td>
#       <td id="T_eb9b3_row6_col4" class="data row6 col4" >False</td>
#       <td id="T_eb9b3_row6_col5" class="data row6 col5" >2253</td>
#       <td id="T_eb9b3_row6_col6" class="data row6 col6" >915</td>
#       <td id="T_eb9b3_row6_col7" class="data row6 col7" >593</td>
#       <td id="T_eb9b3_row6_col8" class="data row6 col8" >3</td>
#       <td id="T_eb9b3_row6_col9" class="data row6 col9" >189</td>
#     </tr>
#     <tr>
#       <th id="T_eb9b3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eb9b3_row7_col0" class="data row7 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row7_col1" class="data row7 col1" >2015-01-04 07:50:25</td>
#       <td id="T_eb9b3_row7_col2" class="data row7 col2" >False</td>
#       <td id="T_eb9b3_row7_col3" class="data row7 col3" >False</td>
#       <td id="T_eb9b3_row7_col4" class="data row7 col4" >False</td>
#       <td id="T_eb9b3_row7_col5" class="data row7 col5" >2253</td>
#       <td id="T_eb9b3_row7_col6" class="data row7 col6" >915</td>
#       <td id="T_eb9b3_row7_col7" class="data row7 col7" >587</td>
#       <td id="T_eb9b3_row7_col8" class="data row7 col8" >3</td>
#       <td id="T_eb9b3_row7_col9" class="data row7 col9" >195</td>
#     </tr>
#     <tr>
#       <th id="T_eb9b3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eb9b3_row8_col0" class="data row8 col0" >54a998989cd118469400024d</td>
#       <td id="T_eb9b3_row8_col1" class="data row8 col1" >2015-01-04 07:50:34</td>
#       <td id="T_eb9b3_row8_col2" class="data row8 col2" >False</td>
#       <td id="T_eb9b3_row8_col3" class="data row8 col3" >False</td>
#       <td id="T_eb9b3_row8_col4" class="data row

# %%
env.step(0)
# Out:
# (1420354149.0, 0, False, False, {})

# %%
env.render()
# Out:
# <style type="text/css">
# #T_21932_row1_col0, #T_21932_row1_col1, #T_21932_row1_col2, #T_21932_row1_col3, #T_21932_row1_col4, #T_21932_row1_col5, #T_21932_row1_col6, #T_21932_row1_col7, #T_21932_row1_col8, #T_21932_row1_col9 {
#   background-color: yellow;
# }
# </style>
# <table id="T_21932">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21932_level0_col0" class="col_heading level0 col0" >user_id</th>
#       <th id="T_21932_level0_col1" class="col_heading level0 col1" >timestamp</th>
#       <th id="T_21932_level0_col2" class="col_heading level0 col2" >ts_diff</th>
#       <th id="T_21932_level0_col3" class="col_heading level0 col3" >user_diff</th>
#       <th id="T_21932_level0_col4" class="col_heading level0 col4" >new_session_mark</th>
#       <th id="T_21932_level0_col5" class="col_heading level0 col5" >session</th>
#       <th id="T_21932_level0_col6" class="col_heading level0 col6" >user</th>
#       <th id="T_21932_level0_col7" class="col_heading level0 col7" >target</th>
#       <th id="T_21932_level0_col8" class="col_heading level0 col8" >fold</th>
#       <th id="T_21932_level0_col9" class="col_heading level0 col9" >time_passed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21932_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21932_row0_col0" class="data row0 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row0_col1" class="data row0 col1" >2015-01-04 07:47:10</td>
#       <td id="T_21932_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_21932_row0_col3" class="data row0 col3" >True</td>
#       <td id="T_21932_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_21932_row0_col5" class="data row0 col5" >2253</td>
#       <td id="T_21932_row0_col6" class="data row0 col6" >915</td>
#       <td id="T_21932_row0_col7" class="data row0 col7" >782</td>
#       <td id="T_21932_row0_col8" class="data row0 col8" >3</td>
#       <td id="T_21932_row0_col9" class="data row0 col9" >0</td>
#     </tr>
#     <tr>
#       <th id="T_21932_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_21932_row1_col0" class="data row1 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row1_col1" class="data row1 col1" >2015-01-04 07:49:09</td>
#       <td id="T_21932_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_21932_row1_col3" class="data row1 col3" >False</td>
#       <td id="T_21932_row1_col4" class="data row1 col4" >False</td>
#       <td id="T_21932_row1_col5" class="data row1 col5" >2253</td>
#       <td id="T_21932_row1_col6" class="data row1 col6" >915</td>
#       <td id="T_21932_row1_col7" class="data row1 col7" >663</td>
#       <td id="T_21932_row1_col8" class="data row1 col8" >3</td>
#       <td id="T_21932_row1_col9" class="data row1 col9" >119</td>
#     </tr>
#     <tr>
#       <th id="T_21932_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_21932_row2_col0" class="data row2 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row2_col1" class="data row2 col1" >2015-01-04 07:49:24</td>
#       <td id="T_21932_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_21932_row2_col3" class="data row2 col3" >False</td>
#       <td id="T_21932_row2_col4" class="data row2 col4" >False</td>
#       <td id="T_21932_row2_col5" class="data row2 col5" >2253</td>
#       <td id="T_21932_row2_col6" class="data row2 col6" >915</td>
#       <td id="T_21932_row2_col7" class="data row2 col7" >648</td>
#       <td id="T_21932_row2_col8" class="data row2 col8" >3</td>
#       <td id="T_21932_row2_col9" class="data row2 col9" >134</td>
#     </tr>
#     <tr>
#       <th id="T_21932_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_21932_row3_col0" class="data row3 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row3_col1" class="data row3 col1" >2015-01-04 07:49:25</td>
#       <td id="T_21932_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_21932_row3_col3" class="data row3 col3" >False</td>
#       <td id="T_21932_row3_col4" class="data row3 col4" >False</td>
#       <td id="T_21932_row3_col5" class="data row3 col5" >2253</td>
#       <td id="T_21932_row3_col6" class="data row3 col6" >915</td>
#       <td id="T_21932_row3_col7" class="data row3 col7" >647</td>
#       <td id="T_21932_row3_col8" class="data row3 col8" >3</td>
#       <td id="T_21932_row3_col9" class="data row3 col9" >135</td>
#     </tr>
#     <tr>
#       <th id="T_21932_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_21932_row4_col0" class="data row4 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row4_col1" class="data row4 col1" >2015-01-04 07:49:28</td>
#       <td id="T_21932_row4_col2" class="data row4 col2" >False</td>
#       <td id="T_21932_row4_col3" class="data row4 col3" >False</td>
#       <td id="T_21932_row4_col4" class="data row4 col4" >False</td>
#       <td id="T_21932_row4_col5" class="data row4 col5" >2253</td>
#       <td id="T_21932_row4_col6" class="data row4 col6" >915</td>
#       <td id="T_21932_row4_col7" class="data row4 col7" >644</td>
#       <td id="T_21932_row4_col8" class="data row4 col8" >3</td>
#       <td id="T_21932_row4_col9" class="data row4 col9" >138</td>
#     </tr>
#     <tr>
#       <th id="T_21932_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_21932_row5_col0" class="data row5 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row5_col1" class="data row5 col1" >2015-01-04 07:49:58</td>
#       <td id="T_21932_row5_col2" class="data row5 col2" >False</td>
#       <td id="T_21932_row5_col3" class="data row5 col3" >False</td>
#       <td id="T_21932_row5_col4" class="data row5 col4" >False</td>
#       <td id="T_21932_row5_col5" class="data row5 col5" >2253</td>
#       <td id="T_21932_row5_col6" class="data row5 col6" >915</td>
#       <td id="T_21932_row5_col7" class="data row5 col7" >614</td>
#       <td id="T_21932_row5_col8" class="data row5 col8" >3</td>
#       <td id="T_21932_row5_col9" class="data row5 col9" >168</td>
#     </tr>
#     <tr>
#       <th id="T_21932_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_21932_row6_col0" class="data row6 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row6_col1" class="data row6 col1" >2015-01-04 07:50:19</td>
#       <td id="T_21932_row6_col2" class="data row6 col2" >False</td>
#       <td id="T_21932_row6_col3" class="data row6 col3" >False</td>
#       <td id="T_21932_row6_col4" class="data row6 col4" >False</td>
#       <td id="T_21932_row6_col5" class="data row6 col5" >2253</td>
#       <td id="T_21932_row6_col6" class="data row6 col6" >915</td>
#       <td id="T_21932_row6_col7" class="data row6 col7" >593</td>
#       <td id="T_21932_row6_col8" class="data row6 col8" >3</td>
#       <td id="T_21932_row6_col9" class="data row6 col9" >189</td>
#     </tr>
#     <tr>
#       <th id="T_21932_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_21932_row7_col0" class="data row7 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row7_col1" class="data row7 col1" >2015-01-04 07:50:25</td>
#       <td id="T_21932_row7_col2" class="data row7 col2" >False</td>
#       <td id="T_21932_row7_col3" class="data row7 col3" >False</td>
#       <td id="T_21932_row7_col4" class="data row7 col4" >False</td>
#       <td id="T_21932_row7_col5" class="data row7 col5" >2253</td>
#       <td id="T_21932_row7_col6" class="data row7 col6" >915</td>
#       <td id="T_21932_row7_col7" class="data row7 col7" >587</td>
#       <td id="T_21932_row7_col8" class="data row7 col8" >3</td>
#       <td id="T_21932_row7_col9" class="data row7 col9" >195</td>
#     </tr>
#     <tr>
#       <th id="T_21932_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_21932_row8_col0" class="data row8 col0" >54a998989cd118469400024d</td>
#       <td id="T_21932_row8_col1" class="data row8 col1" >2015-01-04 07:50:34</td>
#       <td id="T_21932_row8_col2" class="data row8 col2" >False</td>
#       <td id="T_21932_row8_col3" class="data row8 col3" >False</td>
#       <td id="T_21932_row8_col4" class="data row

# %%
env.step(0)
# Out:
# (1420354164.0, 119, False, False, {})
